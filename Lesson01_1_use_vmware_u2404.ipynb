# %% [markdown]
# # 在Windows系统下使用Ubuntu虚拟机来连接机器人进行开发

# %% [markdown]
# ### 1. 安装VMware

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. 下载和解压Ubuntu镜像

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. 打开VMware，打开解压后的Ubuntu镜像文件夹，双击`.vmx`文件启动虚拟机

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. 开启虚拟机后，输入用户名和密码登录Ubuntu系统
#
# 用户名和密码均为：`daojie`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. 设置Ubuntu系统的网络连接为桥接模式，桥接到宿主机的网络接口
#
# 注意： 首先要将网线连接到机器狗身上的网络接口，然后在VMware中选择桥接到该接口，否则虚拟机无法访问网络。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 在Ubuntu系统中打开终端，输入以下命令ping宿主机的IP地址，验证网络连接是否成功

# %%
ping ping 192.168.123.161
