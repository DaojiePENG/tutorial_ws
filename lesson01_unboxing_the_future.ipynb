# %% [markdown]
# # Lesson01. Unboxing the future -你的第一台機器狗

# %% [markdown]
# 教學主題：破冰與初體驗，感受物理世界的AI。
#
# 核心目標：消除對程式設計的恐懼，建立與機器人的情感連結。親手完成開發環境的搭建。
#
# 1. 前40分鐘(動手玩)：開箱與介紹：認識宇樹Go2機器狗的各個部位。
#
# 2. App遙控體驗：使用官方App遙控Go2做出站立、趴下、跳躍、翻跟斗等動作，立刻感受其驚人的運動能力。
#
# 3. 中間20分鐘(聊聊天)：介紹宇樹科技及其Go2與G1應用影片。
#
# 4. 後60分鐘(做準備)：環境搭建工作坊：安裝Python、VS Code與SDK。

# %% [markdown]
# ## 1.1 Let's play !!!

# %% [markdown]
# ### 09:00-09:40 Free play with Go2 using keyboard and APP
#
# Scan the code to download the APP: https://www.unitree.com/app/go2
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 09:40-10:00 Short break (Videos)

# %% [markdown]
# ### Go2:
#
# https://www.bilibili.com/video/BV1Gj421Q7ji/?spm_id_from=333.337.search-card.all.click
#
# https://www.bilibili.com/video/BV1vAbheVEHy/?spm_id_from=333.337.search-card.all.click
#
# https://www.bilibili.com/video/BV1zZ421N7Wc/?spm_id_from=333.337.search-card.all.click
#
# ### G1:
#
# https://www.bilibili.com/video/BV1qa2xBJEXK/?spm_id_from=333.337.search-card.all.click
#
# https://www.bilibili.com/video/BV1b319ByEdM/?spm_id_from=333.337.search-card.all.click
#
# https://www.bilibili.com/video/BV1S93EzEEA8/?spm_id_from=333.337.search-card.all.click

# %% [markdown]
# ## 1.2 Get into the Python World

# %% [markdown]
# ### 10:00-10:20 Install Python

# %% [markdown]
# Click the link: https://www.anaconda.com/download
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### install anaconda
# ```bash
# bash Miniaconda_xxx.sh
# ```
#
# For more details (Step by step instructions), follow the link: https://blog.csdn.net/weixin_51455837/article/details/144232106

# %% [markdown]
# ## 1.3 Install VSCode

# %% [markdown]
# ### 10:20-10:40 Install VSCode

# %% [markdown]
# Click the link to download vscode: https://code.visualstudio.com/download
#
# ![image.png](attachment:image.png)

# %% [markdown]
# For more details (Step by step instructions), follow the link: https://blog.csdn.net/qq_45657541/article/details/147171627

# %% [markdown]
# ## 1.4 Install Unitree's Python SDK

# %% [markdown]
# ### 10:40-11:00 Install Unitree Python SDK

# %% [markdown]
# Click the link for Unitree python SDK: https://github.com/unitreerobotics/unitree_ros2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# follow the instruction to install unitree's python sdk:
#
# ```bash
# cd ~
# sudo apt install python3-pip
# git clone https://github.com/unitreerobotics/unitree_sdk2_python.git
# cd unitree_sdk2_python
#
# pip install -e . -i https://pypi.tuna.tsinghua.edu.cn/simple
# ```
