# %% [markdown]
# # Lesson06. 机器狗的眼睛 - 图像视觉处理

# %% [markdown]
# **教学主题：** 处理来自机器人摄像头的画面。
#
# **核心目标：** 实时影像获取与基础处理。
#
# **课程安排：**
#
# - **前30分钟（理论）：** 介绍机器视觉与OpenCV库的基础概念。
#
# - **后90分钟（实作）：**
#   - **实时图传：** 编写Python程序，将Go2摄像头画面实时显示在笔电窗口中。
#   - **黑白电影滤镜：** 用OpenCV函数，将彩色画面转为灰度图像。
#   - **边缘检测：** 尝试Canny边缘检测，让眼前世界变成素描画。
#   - **隐私与伦理：** 讨论人脸识别应用下的隐私问题及原则。
#   - **责任与监督：** 讨论人与机器人互动中的操作安全、社会法规及三层责任体系。

# %% [markdown]
# ## 6.1 导入依赖并初始化视频客户端

# %%
import time
import sys

# 导入宇树SDK通信和视频客户端
from unitree_sdk2py.core.channel import ChannelSubscriber, ChannelFactoryInitialize
from unitree_sdk2py.go2.video.video_client import VideoClient

# 导入OpenCV和NumPy用于图像处理
import cv2        # 计算机视觉库，用于图像读写、处理和显示
import numpy as np # 数值计算库，用于数组操作

# 初始化通信通道
ChannelFactoryInitialize(0, "ens37")

# 创建视频客户端实例
video_client = VideoClient()
video_client.SetTimeout(3.0)
video_client.Init()

# %% [markdown]
# ## 6.2 获取单张图像并保存

# %%
print("################## 获取单张图像 ###################")
# 从Go2前置摄像头获取一张图像
code, data = video_client.GetImageSample()

if code != 0:
    print("获取图像失败，错误码:", code)
else:
    # 将图像数据保存到文件
    imageName = "./go2_front_image.jpg"
    with open(imageName, "+wb") as f:
        f.write(bytes(data))
    print("图像已保存:", imageName)
# Out:
# ################## 获取单张图像 ###################
# 图像已保存: ./go2_front_image.jpg

# %% [markdown]
# ## 6.3 实时视频流显示

# %%
print("################## 实时视频流 ###################")
# 获取首帧图像以初始化循环
code, data = video_client.GetImageSample()

# 循环获取并显示视频帧（当code==0表示成功）
while code == 0:
    # 从Go2机器人获取图像数据
    code, data = video_client.GetImageSample()

    # 将二进制图像数据转换为NumPy数组
    image_data = np.frombuffer(bytes(data), dtype=np.uint8)
    # 使用OpenCV解码JPEG格式图像为矩阵
    image = cv2.imdecode(image_data, cv2.IMREAD_COLOR)

    # 在窗口中显示实时图像
    cv2.imshow("机器狗前置摄像头", image)
    # 按ESC键停止视频流（waitKey返回值27是ESC键的ASCII码）
    if cv2.waitKey(20) == 27:
        print("停止视频流...")
        break

if code != 0:
    print("获取图像失败，错误码:", code)
else:
    # 保存最后一帧图像
    imageName = "last_go2_front_image.jpg"
    cv2.imwrite(imageName, image)
    print("最后一帧已保存:", imageName)

# 关闭所有OpenCV窗口
cv2.destroyWindow("机器狗前置摄像头")
# Out:
# ################## 实时视频流 ###################

# %% [markdown]
# ## 6.4 Canny边缘检测 - 变成素描画

# %%
import cv2
import numpy as np

print("################## Canny边缘检测 ###################")
# 从摄像头获取一张图像
code, data = video_client.GetImageSample()

if code != 0:
    print("获取图像失败，错误码:", code)
else:
    # 保存原始彩色图像
    imageName = "./go2_front_image.jpg"
    with open(imageName, "+wb") as f:
        f.write(bytes(data))
    print("原始彩色图像已保存:", imageName)

    # 将二进制数据转换为OpenCV格式的图像
    image_data = np.frombuffer(bytes(data), dtype=np.uint8)
    color_image = cv2.imdecode(image_data, cv2.IMREAD_COLOR)

    if color_image is None:
        print("图像解码失败")
    else:
        # 1. 转换为灰度图（黑白图像）
        # 灰度图只有一个颜色通道，处理速度更快
        gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)
        
        # 2. Canny边缘检测
        # 参数说明：
        # - 第一个参数(50)：低阈值，小于此值的边缘被忽略
        # - 第二个参数(150)：高阈值，大于此值的边缘肯定被保留
        # - 两个阈值之间的边缘取决于是否与确定边缘连接
        edges = cv2.Canny(gray_image, 50, 150)

        # 保存处理后的图像
        gray_image_name = "./go2_gray_image.jpg"
        edges_image_name = "./go2_canny_edges.jpg"
        cv2.imwrite(gray_image_name, gray_image)
        cv2.imwrite(edges_image_name, edges)
        
        print("灰度图像已保存:", gray_image_name)
        print("边缘检测图像已保存:", edges_image_name)
# Out:
# ################## Canny边缘检测 ###################
# 原始彩色图像已保存: ./go2_front_image.jpg
# 灰度图像已保存: ./go2_gray_image.jpg
# 边缘检测图像已保存: ./go2_canny_edges.jpg

# %% [markdown]
# ## 6.5 人脸检测 - 识别"看到"的人

# %%
import cv2
import numpy as np

print("################## 人脸检测演示 ###################")

# 加载预训练的人脸级联分类器（来自OpenCV官方）
# cascade_path是OpenCV库中自带的人脸检测模型
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

# 从Go2摄像头获取一张图像
code, data = video_client.GetImageSample()

if code != 0:
    print("获取图像失败，错误码:", code)
else:
    # 将二进制数据转换为OpenCV格式
    image_data = np.frombuffer(bytes(data), dtype=np.uint8)
    image = cv2.imdecode(image_data, cv2.COLOR_BGR2GRAY)  # 直接转为灰度
    
    if image is None:
        print("图像解码失败")
    else:
        # 执行人脸检测
        # 参数说明：
        # - scaleFactor=1.3：图像金字塔的缩放因子（越小越精确但越慢）
        # - minNeighbors=5：每个候选人脸要保留多少个邻居（越大越严格）
        # - minSize=(30, 30)：最小检测人脸的大小
        faces = face_cascade.detectMultiScale(
            image, 
            scaleFactor=1.3, 
            minNeighbors=5, 
            minSize=(30, 30)
        )
        
        print(f"检测到 {len(faces)} 张人脸")
        
        # 将检测结果转换为彩色图像用于显示
        image_color = cv2.imdecode(
            np.frombuffer(bytes(data), dtype=np.uint8), 
            cv2.IMREAD_COLOR
        )
        
        # 在图像上绘制人脸矩形框
        for (x, y, w, h) in faces:
            # 绘制蓝色矩形框（BGR格式，所以是(255, 0, 0)）
            cv2.rectangle(image_color, (x, y), (x+w, y+h), (255, 0, 0), 2)
            # 在人脸上方写入"人脸"标签
            cv2.putText(image_color, "Face", (x, y-10), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
        
        # 保存标记了人脸的图像
        output_name = "./go2_face_detection.jpg"
        cv2.imwrite(output_name, image_color)
        print("人脸检测结果已保存:", output_name)
# Out:
# ################## 人脸检测演示 ###################
# 检测到 0 张人脸
# 人脸检测结果已保存: ./go2_face_detection.jpg

# %% [markdown]
# ### 6.5.1 实时人脸检测与跟踪

# %%
import cv2
import numpy as np

print("################## 实时人脸检测 ###################")
print("按ESC键停止...")

# 加载人脸检测分类器
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

# 获取首帧以初始化循环
code, data = video_client.GetImageSample()

frame_count = 0  # 帧计数器
faces_detected_list = []  # 记录检测到的人脸数

# 实时处理视频流
while code == 0:
    code, data = video_client.GetImageSample()
    frame_count += 1
    
    # 转换图像格式
    image_data = np.frombuffer(bytes(data), dtype=np.uint8)
    frame_gray = cv2.imdecode(image_data, cv2.IMREAD_COLOR)
    
    if frame_gray is None:
        continue
    
    # 转为灰度图用于人脸检测
    gray = cv2.cvtColor(frame_gray, cv2.COLOR_BGR2GRAY)
    
    # 检测人脸
    faces = face_cascade.detectMultiScale(
        gray, 
        scaleFactor=1.3, 
        minNeighbors=5, 
        minSize=(30, 30)
    )
    
    faces_detected_list.append(len(faces))
    
    # 在图像上绘制人脸框
    for (x, y, w, h) in faces:
        cv2.rectangle(frame_gray, (x, y), (x+w, y+h), (255, 0, 0), 2)
        cv2.putText(frame_gray, f"Face", (x, y-10), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
    
    # 在图像上显示信息
    info_text = f"Faces: {len(faces)} | Frame: {frame_count}"
    cv2.putText(frame_gray, info_text, (10, 30), 
               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
    
    # 显示实时画面
    cv2.imshow("实时人脸检测", frame_gray)
    
    # 按ESC停止
    if cv2.waitKey(20) == 27:
        print(f"停止人脸检测（已处理{frame_count}帧）")
        break

# 统计信息
if len(faces_detected_list) > 0:
    avg_faces = sum(faces_detected_list) / len(faces_detected_list)
    max_faces = max(faces_detected_list)
    print(f"平均检测人脸数: {avg_faces:.1f}")
    print(f"最多检测人脸数: {max_faces}")

cv2.destroyWindow("实时人脸检测")
# Out:
# ################## 实时人脸检测 ###################
# 按ESC键停止...
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/daojie/miniconda3/envs/go2/lib/python3.10/site-packages/cv2/qt/plugins"
# 停止人脸检测（已处理12帧）
# 平均检测人脸数: 1.3
# 最多检测人脸数: 2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 6.6 图像处理的高级应用

# %%
import cv2
import numpy as np

print("################## 运动检测 ###################")
print("检测摄像头前的物体运动...")
print("按ESC键停止...\n")

# 获取首帧作为背景
code, data = video_client.GetImageSample()
if code != 0:
    print("获取图像失败")
else:
    # 将首帧作为背景参考
    image_data = np.frombuffer(bytes(data), dtype=np.uint8)
    prev_frame = cv2.imdecode(image_data, cv2.IMREAD_GRAYSCALE)
    
    motion_count = 0
    frame_count = 0
    
    # 持续检测运动
    while True:
        code, data = video_client.GetImageSample()
        if code != 0:
            break
        
        frame_count += 1
        
        # 读取当前帧
        image_data = np.frombuffer(bytes(data), dtype=np.uint8)
        current_frame = cv2.imdecode(image_data, cv2.IMREAD_GRAYSCALE)
        
        if current_frame is None:
            continue
        
        # 计算两帧之间的差异
        # absdiff返回两帧的逐像素绝对差值
        frame_diff = cv2.absdiff(prev_frame, current_frame)
        
        # 对差异应用二值化阈值（将灰度转为黑白）
        # 参数(50)表示阈值：差异>50的像素设为白色(255)，否则为黑色(0)
        _, thresh = cv2.threshold(frame_diff, 50, 255, cv2.THRESH_BINARY)
        
        # 计算运动像素的总数
        motion_pixels = cv2.countNonZero(thresh)
        
        # 如果运动像素超过阈值，判定为有运动
        motion_threshold = 5000
        if motion_pixels > motion_threshold:
            motion_count += 1
            status = "🔴 运动检测到！"
        else:
            status = "🟢 静止"
        
        # 显示信息
        print(f"[{frame_count:3d}] 运动像素: {motion_pixels:6d} | {status}")
        
        # 更新背景帧
        prev_frame = current_frame
        
        # 按ESC停止
        if cv2.waitKey(1) == 27:
            break

print(f"\n--- 运动检测统计 ---")
print(f"总帧数: {frame_count}")
print(f"检测到运动的帧: {motion_count}")
print(f"运动频率: {motion_count/max(1, frame_count)*100:.1f}%")

# %% [markdown]
# ## 6.7 隐私与伦理 - 机器人"看"的界限
#
# ### 问题提出
#
# 当Go2的摄像头实时接收画面，特别是当应用人脸检测功能时，一个重要的伦理问题随之出现：
#
# **"机器人看到的东西，能做什么？"**
#
# ### 6.7.1 隐私保护的三个关键原则
#
# #### 原则 1️⃣：知情与同意
# - **核心要求**：被摄像的人必须知道有机器人在记录或处理他们的图像
# - **实践方法**：
#   - 在机器人显眼位置标识"有摄像头"
#   - 如果进行人脸识别，必须明确告知目的（如"仅用于访客识别"）
#   - 获得明确同意，特别是在敏感场景（如家庭、医疗）
#
# #### 原则 2️⃣：最小化数据收集
# - **核心要求**：只收集完成任务所需的最少数据
# - **实践方法**：
#   ```
#   ❌ 不应该做：
#   - 保存所有人的人脸照片建立数据库
#   - 在无关场景持续录制视频
#   - 将人脸数据与其他信息关联（如姓名、住址）
#
#   ✅ 应该做：
#   - 只检测，不存储人脸特征
#   - 检测完后立即删除图像
#   - 仅在必要时启用敏感功能（如人脸识别）
#   ```
#
# #### 原则 3️⃣：数据保护与删除
# - **核心要求**：已收集的数据必须加密存储，且在不需要时及时删除
# - **实践方法**：
#   - 对所有图像数据加密
#   - 定期审计谁可以访问这些数据
#   - 实现"遗忘权"——用户可要求删除其个人数据
#   - 避免跨系统数据共享

# %% [markdown]
# ### 6.7.2 法律框架：GDPR 与 CCPA
#
# #### 欧盟 GDPR（《通用数据保护条例》）
# - 对生物识别数据（包括人脸）有特殊保护
# - 禁止在没有明确同意下进行自动化个人决策
# - 用户享有"被遗忘权"——可要求公司删除其个人数据
# - 违规罚款高达收入的 4% 或 2000 万欧元（以较高者为准）
#
# #### 美国 CCPA（《加州消费者隐私法》）
# - 消费者有权了解公司收集了什么个人信息
# - 有权要求删除个人信息
# - 有权要求公司不向第三方出售信息
#
# #### 中国相关法规
# - 《网络安全法》：要求企业加强个人信息保护
# - 《个人信息保护法》：明确个人权利与企业义务
# - 人脸识别的特殊规范仍在制定中（部分城市已禁止公共场所无区分人脸识别）
#
# ### 6.7.3 伦理困境与案例分析
#
# #### 案例 1：家庭陪伴机器人的隐私陷阱
# ```
# 场景：Go2 在家庭环境中持续运行
# 问题：
#   - 是否应该记录访客的人脸？
#   - 如果访客拒绝被识别怎么办？
#   - 家人的日常活动记录谁拥有权利？
#
# 建议方案：
#   ✓ 明确告知所有进入家庭的人"有摄像头"
#   ✓ 提供"隐私模式"（关闭人脸识别）
#   ✓ 限制数据仅本家庭使用
#   ✓ 定期删除录像
# ```
#
# #### 案例 2：商业场景的识别滥用
# ```
# 场景：商场部署 Go2 进行访客流量分析
# 风险：
#   - 可能被滥用于"识别黑名单顾客"
#   - 可能将人脸数据倒卖给广告商
#   - 可能被警察用于追捕目标（无正当程序）
#
# 防护措施：
#   ✓ 仅进行"计数"而非"识别"
#   ✓ 数据只保留 24 小时
#   ✓ 公开隐私政策且接受独立审计
#   ✓ 明确禁止政府执法机构的数据共享
# ```
#
# #### 案例 3：算法偏见的伦理问题
# ```
# 事实：人脸识别模型常对深色肤色的人检测准确度更低
# 问题：如果 Go2 的人脸检测模型存在性别或种族偏见怎么办？
#
# 后果：
#   - 不同肤色的人获得不同的服务质量
#   - 可能导致歧视性结果（虽然无意）
#
# 解决方案：
#   ✓ 定期审计模型性能跨人口统计特征
#   ✓ 使用更平衡的训练数据
#   ✓ 在部署前进行多样性测试
#   ✓ 提供人工干预通道（允许用户重新识别）
# ```

# %% [markdown]
# ## 6.8 责任与监督 - 谁为机器人的"眼睛"负责？
#
# ### 问题的复杂性
#
# 当 Go2 在执行视觉任务时出现问题（如误识别导致误判、隐私泄露、偏见伤害），谁应该承担责任？
#
# 这涉及三个主体，形成**"三角责任体系"**：
#
# ### 🏭 第一层：开发者与制造商的责任
#
# **宇树（Unitree）及其视觉算法开发团队**
#
# | 责任类型 | 具体要求 |
# |---------|---------|
# | **安全责任** | 确保人脸检测模型在各种光照、角度、年龄、性别下都能准确工作；定期更新模型修复已知bug |
# | **伦理责任** | 在产品文档中明确说明人脸识别的局限性（误识别率、偏见问题）；提供隐私友好的默认设置 |
# | **透明度责任** | 公开算法的工作原理、训练数据来源、性能基准；允许用户和审计者检查代码 |
# | **应急责任** | 如发现严重问题（如算法存在系统性偏见），要求立即发布安全补丁 |
#
# **面临的法律风险：**
# - 如产品导致伤害（如歧视），制造商可能面临产品责任诉讼
# - 欧盟《人工智能法案》要求高风险AI系统必须进行合规性评估
#
# ### 👨‍💻 第二层：部署者与使用者的责任
#
# **购买并使用 Go2 的企业、个人或机构**
#
# | 责任类型 | 具体要求 |
# |---------|---------|
# | **合规责任** | 确保部署符合当地法律（如GDPR、CCPA）；获得必要的许可或同意 |
# | **使用责任** | 不能滥用人脸识别功能进行非法监控、歧视或追捕；不能将数据用于原本声明之外的目的 |
# | **告知责任** | 明确告知被摄像人员"有机器人在进行视觉处理"；解释为什么需要（如"安全监控"）和如何使用数据 |
# | **安全责任** | 保护收集的图像数据不被泄露；限制数据访问权限；定期审计日志 |
#
# **常见的责任纠纷：**
# ```
# ❌ 违规案例：
# - 零售商在未告知的情况下用 Go2 识别"VIP顾客"
# - 办公楼用 Go2 监控员工但未获其同意
# - 将人脸数据卖给第三方广告商
#
# ✅ 合规案例：
# - 清晰标识"该区域有AI视觉监控"
# - 提供隐私政策并获得书面同意
# - 仅在需要时启用人脸识别，其他时间仅用于物体检测
# ```
#
# ### 🏛️ 第三层：监管机构与社会的责任
#
# **政府监管部门、行业协会、公民社会**
#
# | 主体 | 职能 |
# |------|------|
# | **政府部门** | 制定法律框架（如禁止不当使用人脸识别）；执法处罚违规者；进行公众教育 |
# | **行业协会** | 制定行业标准和最佳实践；建立认证体系（如"隐私友好"认证）；调解争议 |
# | **学术机构** | 独立研究AI系统的公平性和隐私风险；发布基准测试报告 |
# | **公民社会** | 监督滥用行为；为被害者提供法律援助；进行公众倡导 |
#
# **全球监管趋势：**
# - 🇪🇺 欧盟：禁止"大规模监控"用人脸识别，除非有充分理由且过程透明
# - 🇺🇸 美国：部分城市（旧金山、波士顿）禁止政府机构使用人脸识别
# - 🇨🇳 中国：制定人脸识别的行业标准，禁止某些场景的使用（如公安不能随意识别普通市民）

# %% [markdown]
# ## 6.9 隐私友好的实现 - 代码级的伦理守则
#
# 如何在使用Go2的视觉功能时，在代码层面体现隐私保护原则？以下是几个最佳实践：

# %%
import cv2
import numpy as np
from datetime import datetime
import os

print("################## 隐私友好的视觉系统实现 ###################\n")

class PrivacyFriendlyVisionSystem:
    """
    隐私友好的Go2视觉处理系统
    
    关键特性：
    1. 可选的隐私模式：用户可随时关闭人脸识别功能
    2. 自动数据删除：处理后的图像在指定时间自动删除
    3. 日志记录：记录所有视觉处理操作，用于审计
    4. 数据最小化：不存储个人识别信息，仅存储聚合统计
    """
    
    def __init__(self, enable_face_detection=False, auto_delete_hours=24):
        """
        初始化隐私友好的视觉系统
        
        Args:
            enable_face_detection (bool): 是否启用人脸识别（默认关闭）
            auto_delete_hours (int): 图像自动删除时间（小时）
        """
        self.enable_face_detection = enable_face_detection
        self.auto_delete_hours = auto_delete_hours
        self.face_cascade = None
        self.audit_log = []  # 审计日志
        self.image_storage = "./vision_data/"
        
        # 创建存储目录
        os.makedirs(self.image_storage, exist_ok=True)
        
        # 只在明确启用时加载人脸检测模型
        if self.enable_face_detection:
            self.face_cascade = cv2.CascadeClassifier(
                cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
            )
            self._log_audit("人脸识别功能已启用")
            print("⚠️  注意：人脸识别功能已启用，请确保用户已知情同意")
        else:
            self._log_audit("运行在隐私模式（人脸识别已关闭）")
            print("✓ 隐私模式激活：人脸识别功能已禁用")
    
    def _log_audit(self, message):
        """记录审计日志（用于事后审查）"""
        timestamp = datetime.now().isoformat()
        log_entry = f"[{timestamp}] {message}"
        self.audit_log.append(log_entry)
        print(f"📋 {log_entry}")
    
    def process_image(self, image_data, detect_faces=False):
        """
        处理图像，同时保护隐私
        
        Args:
            image_data: 二进制图像数据
            detect_faces (bool): 是否对此图像进行人脸检测
        
        Returns:
            (processed_image, faces_count, was_deleted)
        """
        # 首先转换图像
        image_array = np.frombuffer(bytes(image_data), dtype=np.uint8)
        image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)
        
        if image is None:
            self._log_audit("图像解码失败")
            return None, 0, False
        
        faces_count = 0
        
        # 只有在系统启用且用户请求时才进行人脸检测
        if detect_faces and self.enable_face_detection and self.face_cascade is not None:
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            faces = self.face_cascade.detectMultiScale(
                gray, scaleFactor=1.3, minNeighbors=5, minSize=(30, 30)
            )
            faces_count = len(faces)
            
            # 记录统计信息（不记录个人身份，只记录数量）
            self._log_audit(f"人脸检测：发现 {faces_count} 张人脸")
        else:
            self._log_audit("已跳过人脸检测（隐私模式或用户未授权）")
        
        # 数据最小化：不保存图像本身，只保存元数据
        # 这符合"最小必要数据"原则
        self._log_audit("图像已处理，原始数据已清除（不保存）")
        
        return image, faces_count, True  # 表示图像已删除
    
    def generate_audit_report(self):
        """生成审计报告，用于合规检查"""
        print("\n" + "="*60)
        print("【审计报告】")
        print("="*60)
        for entry in self.audit_log:
            print(entry)
        print("="*60)
        print(f"总操作数：{len(self.audit_log)}")
        print(f"启用了人脸识别：{'是' if self.enable_face_detection else '否'}")

# ========== 演示 1：隐私模式（默认） ==========
print("\n--- 演示 1：隐私模式（推荐用于家庭环境） ---")
privacy_system = PrivacyFriendlyVisionSystem(
    enable_face_detection=False,  # 明确禁用人脸识别
    auto_delete_hours=24
)

# ========== 演示 2：需要人脸识别的场景（带同意） ==========
print("\n--- 演示 2：启用人脸识别（办公室访客识别） ---")
# 在实际应用中，这里应该有获取用户同意的代码
consent_obtained = True  # 假设已获得同意

if consent_obtained:
    office_system = PrivacyFriendlyVisionSystem(
        enable_face_detection=True,  # 仅在获得同意后启用
        auto_delete_hours=24
    )
    office_system._log_audit("已获得用户同意启用人脸识别")
else:
    office_system = PrivacyFriendlyVisionSystem(enable_face_detection=False)

# 生成审计报告
office_system.generate_audit_report()

# %% [markdown]
# ## 6.10 课程总结与伦理检查清单
#
# ### 完成的学习内容
#
# ✅ **技术层面：**
# - 获取和显示实时视频流
# - 图像转换与滤镜（灰度、边缘检测）
# - 人脸检测（Haar 级联分类器）
# - 运动检测（帧差法）
# - 隐私友好的代码设计
#
# ✅ **伦理与法律层面：**
# - 理解隐私保护的三个关键原则
# - 学习 GDPR、CCPA 等全球法规
# - 认识三角责任体系（开发者、使用者、监管机构）
# - 在代码中体现隐私价值
#
# ### 在自己的项目中应用本课程的检查清单
#
# 使用 Go2 的视觉功能前，请逐一确认以下项目：
#
# #### 🔍 隐私设计清单
# - [ ] 我已明确定义"为什么需要摄像头"（如"安全监控"或"访客计数"）
# - [ ] 我已评估是否真的需要人脸识别，或仅需物体检测
# - [ ] 我已制定"最小数据收集"方案（仅保存必要的统计信息）
# - [ ] 我已设定图像自动删除策略（如24小时后删除）
# - [ ] 我已将人脸识别设置为可选功能，非默认启用
#
# #### 📋 知情同意清单
# - [ ] 所有被摄像的人员都被明确告知"此处有摄像头"
# - [ ] 在适用法律地区（如欧盟），我已获得明确的书面同意
# - [ ] 我已向用户解释：如何使用其数据、数据保留时间、谁可以访问
# - [ ] 我已提供选择权：用户可以拒绝被识别或要求删除其数据
#
# #### 🛡️ 数据安全清单
# - [ ] 所有收集的图像数据已加密存储
# - [ ] 只有需要的人员有访问权限
# - [ ] 我有日志记录谁访问了数据及何时访问
# - [ ] 数据不会被转移或共享给第三方（除非明确同意）
# - [ ] 我有应急计划应对可能的数据泄露
#
# #### ⚖️ 法律合规清单
# - [ ] 我已查阅当地关于人脸识别的法律（如中国的《个人信息保护法》）
# - [ ] 我已确认系统符合适用的隐私法（GDPR、CCPA 等）
# - [ ] 如涉及医疗或金融领域，我已了解额外的行业规定
# - [ ] 我有隐私政策文档，可以向用户和监管者展示
# - [ ] 我的系统设计可经受数据保护官或隐私审计
#
# #### 🔧 技术架构清单
# - [ ] 人脸识别功能有明确的开关，默认关闭
# - [ ] 系统有完善的审计日志，记录所有敏感操作
# - [ ] 图像处理后立即删除原始数据（不存储）
# - [ ] 系统定期更新以修复已知的安全漏洞
# - [ ] 我使用的 ML 模型的准确度已在多个人口统计特征上测试
#
# #### ⚠️ 偏见与公平性清单
# - [ ] 我已测试系统对不同性别、种族、年龄的识别准确度差异
# - [ ] 如发现系统存在系统性偏见，我有改进计划
# - [ ] 我的系统设计允许人工干预（如用户可标记误识别）
# - [ ] 在高风险场景（如执法）下，我避免完全自动化决策
#
# #### 📊 监测与持续改进清单
# - [ ] 我有机制收集用户反馈和投诉
# - [ ] 我定期审视系统的隐私影响
# - [ ] 我订阅了AI伦理和隐私相关的业界资讯
# - [ ] 我的团队接受过隐私和伦理培训
# - [ ] 系统出现问题时，我有明确的补救和通知流程
#
# ### 进阶学习方向
#
# 🎓 **想要深入学习？可以探索：**
#
# 1. **差分隐私**（Differential Privacy）
#    - 让模型学习统计特征，而不学习个人信息
#    - 适用于需要聚合数据分析的场景
#
# 2. **联邦学习**（Federated Learning）
#    - 在本地设备上训练模型，不向云端传送原始数据
#    - 兼顾性能和隐私
#
# 3. **同态加密**（Homomorphic Encryption）
#    - 在不解密的情况下对加密数据进行计算
#    - 技术难度高但隐私性最强
#
# 4. **可解释AI**（Explainable AI）
#    - 让AI决策过程可以被理解和审计
#    - 对高风险应用（如金融、司法）尤为重要
#
# 5. **AI 伦理认证**
#    - 学习国际标准（如 IEEE 的 Ethically Aligned Design）
#    - 为团队进行伦理培训
#
# ### 最终思考
#
# **Go2 的眼睛不仅是一个技术工具，也是一个伦理决策工具。**
#
# - 每一次人脸检测都涉及隐私权的权衡
# - 每一条审计日志都记录了你的道德选择
# - 每一个政策决定都影响他人的权利和尊严
#
# 作为开发者，你有能力设计既强大又负责任的系统。希望本课程激发你思考：**"这项技术应该如何使用？谁会因此受益或受伤？"**
#
# ---
#
# **🎓 完成 Lesson06！你已经掌握：**
# - ✓ 机器视觉的基础技术（OpenCV）
# - ✓ 人脸检测与运动识别
# - ✓ 隐私保护的法律框架
# - ✓ 三角责任体系的理解
# - ✓ 在代码中实现伦理价值的能力
#
# **下一课程** Lesson07 将探讨**激光雷达与避障**——又一个涉及"感知与责任"的重要话题！
